# %% [markdown]
# <a href="https://colab.research.google.com/github/jgvroallos/VDA-CPE031-CPE21S4/blob/main/Exercise_8_VDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.1

# %% [markdown]
# Matplotlib Pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, marker='*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, 'o:b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, 'o:b',ms=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, 'o:b',ms=10,mec='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints,'o:b', ms=10, mec='green', mfc='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, ms=10, mec='green', mfc='red', linestyle='--') # dashed
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)

plt.title("Distance Travelled Everyday")
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)

plt.title("Distance Travelled Everyday", loc = "left")
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)

plt.title("Distance Travelled Everyday", loc = "left")
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.grid() # axis = 'x' or 'y'
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)

plt.title("Distance Travelled Everyday", loc = "left")
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.grid(axis ='x', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
# Plot 1
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])
plt.subplot(1,2,1)
plt.plot(xpoints, ypoints)

plt.grid(axis ='x', linestyle = '--', linewidth = 0.5)

# Plot 2
xpoints = np.array([1, 3, 6, 8])
ypoints = np.array([10, 20, 30, 40])
plt.subplot(1,2,2)
plt.plot(xpoints, ypoints)

plt.grid(axis ='x', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.scatter(xpoints, ypoints)

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([10, 20, 30, 40])

plt.scatter(xpoints, ypoints)

plt.grid(axis ='x', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['Student1','Student2','Student3'])
y=np.array([90,85,86])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

g = np.array([35,25,25,15])
grader = ["Grade 1 = 35%", "Grade 2 = 25%", "Grade 3 = 25%", "Grade 4 = 15%"]

plt.pie(g, labels = grader)
plt.show()

# %% [markdown]
# # Laboratory Work

# %% [markdown]
# # PART 1

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,25,30]

plt.plot(x,y)
plt.title("Line Plot Example")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,25,30]

plt.scatter(x,y)
plt.title("Scatter Plot Example")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt

data = [1,2,2,3,3,3,4]

plt.hist(data)
plt.title("Histogram Example")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C']
values =[5, 7, 3]

plt.bar(categories, values)
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [[1.5]*10 + [2]*10 + [3]*10]

plt.boxplot(data)

plt.title("Box Plot Example")
plt.ylabel("Values")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ['A', 'B', 'C']
sizes =[40, 30, 30]

plt.pie(sizes, labels=labels)
plt.title("Pie Chart Example")
plt.show()

# %% [markdown]
# # PART 2

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-4e0ce892-2aac-4c08-ac3a-f7dc046937af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e0ce892-2aac-4c08-ac3a-f7dc046937af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('cars_dataset.csv')
print(df)
# Out:
#          model  year  price transmission  mileage fuelType    tax   mpg  \
# 0           A1  2017  12500       Manual    15735   Petrol  150.0  55.4
# 1           A6  2016  16500    Automatic    36203   Diesel   20.0  64.2
# 2           A1  2016  11000       Manual    29946   Petrol   30.0  55.4
# 3           A4  2017  16800    Automatic    25952   Diesel  145.0  67.3
# 4           A3  2019  17300       Manual     1998   Petrol  145.0  49.6
# ...        ...   ...    ...          ...      ...      ...    ...   ...
# 72430      I30  2016   8680       Manual    25906   Diesel    0.0  78.4
# 72431      I40  2015   7830       Manual    59508   Diesel   30.0  65.7
# 72432      I10  2017   6830       Manual    13810   Petrol   20.0  60.1
# 72433   Tucson  2018  13994       Manual    23313   Petrol  145.0  44.8
# 72434   Tucson  2016  15999    Automatic    11472   Diesel  125.0  57.6
#
#        engineSize     Make
# 0             1.4     audi
# 1             2.0     audi
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72435 entries, 0 to 72434
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         72435 non-null  object
#  1   year          72435 non-null  int64
#  2   price         72435 non-null  int64
#  3   transmission  72435 non-null  object
#  4   mileage       72435 non-null  int64
#  5   fuelType      72435 non-null  object
#  6   tax           72435 non-null  float64
#  7   mpg           72435 non-null  float64
#  8   engineSize    72435 non-null  float64
#  9   Make          72435 non-null  object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 5.5+ MB
# None

# %%
print(df.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 72430    False
# 72431    False
# 72432    False
# 72433    False
# 72434    False
# Length: 72435, dtype: bool

# %% [markdown]
# No data is duplicated

# %%
shortened = df.tail(10)
print(shortened)
# Out:
#            model  year  price transmission  mileage fuelType    tax   mpg  \
# 72425        I10  2018   7200       Manual    17879   Petrol  145.0  60.1
# 72426        I10  2018   7995       Manual     8851   Petrol  145.0  60.1
# 72427        I10  2018   7200       Manual    14788   Petrol  150.0  60.1
# 72428     Tucson  2016  12495       Manual    35000   Diesel   30.0  61.7
# 72429   Santa Fe  2019  29995    Semi-Auto     1567   Diesel  145.0  39.8
# 72430        I30  2016   8680       Manual    25906   Diesel    0.0  78.4
# 72431        I40  2015   7830       Manual    59508   Diesel   30.0  65.7
# 72432        I10  2017   6830       Manual    13810   Petrol   20.0  60.1
# 72433     Tucson  2018  13994       Manual    23313   Petrol  145.0  44.8
# 72434     Tucson  2016  15999    Automatic    11472   Diesel  125.0  57.6
#
#        engineSize     Make
# 72425         1.0  Hyundai
# 72426         1.0  Hyundai
# 72427         1.0  Hyundai
# 72428         1.7  Hyundai
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

year_col = shortened['year']

plt.hist(year_col, color='y')
plt.title("Manufacturing Year of Hyundai Cars")
plt.xlabel("Year")
plt.ylabel("Car Models Released")

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

price = shortened['price']
mileage = shortened['mileage']

plt.scatter(mileage, price)
plt.title("Price to Mileage Correlation")
plt.xlabel("Price")
plt.ylabel("Mileage")
plt.grid(linestyle = '--', linewidth = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

mpg = shortened['mpg']
name = shortened['model']

plt.bar(name, mpg, color='g')
plt.title("Hyundai Car Models' Fuel Efficiency")
plt.xlabel("Model")
plt.ylabel("Fuel Efficiency (in mpg)")

plt.show()
