# %% [markdown]
# <a href="https://colab.research.google.com/github/jgvroallos/VDA-CPE031-CPE21S4/blob/main/Exercise_7_VDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

data = {
        'apples':[3,2,0,1],
        'oranges':[0,3,7,2]
       }

purchases = pd.DataFrame(data)
purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
purchases.to_csv('fruits.csv')

# %%
purchases.to_excel('fruits.xlsx')

# %%
#from google.colab import files
#uploaded = files.upload()

# Google Colab finds the 'saved' file within the directory of this project

data = pd.read_csv('fruits.csv')

purchases = pd.DataFrame(data)

print(purchases)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
# Loading data from the Excel file

data = pd.read_excel('fruits.xlsx')

purchases = pd.DataFrame(data)

print(purchases)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
# Loads first 3 data lines
data.head(3)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7

# %%
# Loads last 3 data lines
data.tail(3)
# Out:
#   Unnamed: 0  apples  oranges
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %% [markdown]
# # Laboratory Processes

# %% [markdown]
# Loading your dataset

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/VDA-Dataset/new-f1-drivers-all-time.csv"
data = pd.read_csv(path)
data.head(5)
# Out:
#          Grand Prix        Date               Winner  \
# 0     Great Britain  1950-05-13         Nino  Farina
# 1            Monaco  1950-05-21  Juan Manuel  Fangio
# 2  Indianapolis 500  1950-05-30      Johnnie Parsons
# 3       Switzerland  1950-06-04         Nino  Farina
# 4           Belgium  1950-06-18  Juan Manuel  Fangio
#
#                         Car   Laps     Time Name Code
# 0                Alfa Romeo   70.0  2:13:24       FAR
# 1                Alfa Romeo  100.0  3:13:19       FAN
# 2  Kurtis Kraft Offenhauser  138.0  2:46:56       PAR
# 3                Alfa Romeo   42.0  2:02:54       FAR
# 4                Alfa Romeo   35.0  2:47:26       FAN

# %% [markdown]
# Creating a dataframe

# %%
data = pd.read_csv(path)
data
# Out:
#             Grand Prix        Date               Winner  \
# 0        Great Britain  1950-05-13         Nino  Farina
# 1               Monaco  1950-05-21  Juan Manuel  Fangio
# 2     Indianapolis 500  1950-05-30      Johnnie Parsons
# 3          Switzerland  1950-06-04         Nino  Farina
# 4              Belgium  1950-06-18  Juan Manuel  Fangio
# ...                ...         ...                  ...
# 1105      Saudi Arabia  2024-03-09      Max  Verstappen
# 1106         Australia  2024-03-24        Carlos  Sainz
# 1107             Japan  2024-04-07      Max  Verstappen
# 1108             China  2024-04-21      Max  Verstappen
# 1109             Miami  2024-05-05        Lando  Norris
#
#                              Car   Laps     Time Name Code
# 0                     Alfa Romeo   70.0  2:13:24       FAR
# 1                     Alfa Romeo  100.0  3:13:19       FAN
# 2       Kurtis Kraft Offenhauser  138.0  2:46:56       PAR
# ...

# %% [markdown]
# Creating a dataframe from a dictionary of lists

# %%
data_dictionary = {
    'Grand Prix': ['Bahrain', 'Saudi Arabia', 'Australia', 'Japan', 'China', 'Miami'],
    'Date': ['2024-03-02', '2024-03-09', '2024-03-24', '2024-04-07', '2024-04-21', '2024-05-05'],
    'Winner': ['Max Verstappen', 'Max Verstappen', 'Carlos Sainz', 'Max Verstappen', 'Max Verstappen', 'Lando Norris'],
    'Car': ['Red Bull Racing', 'Red Bull Racing', 'Ferrari', 'Red Bull Racing', 'Red Bull Racing', 'Mclaren Mercedes'],
    'Laps': [57, 50, 58, 53, 56, 57],
    'Time': ['1:31:45', '1:20:43', '1:20:27', '1:54:24', '1:40:53', '1:30:50']
}

# Grand Prix: Country of the F1 Championship it was held on
# Date: Date of the F1 Championship occured (all held in early 2024)
# Winner: The winner of the F1 Championship
# Car: Name of the F1 participant that won the F1 Championship
# Laps: Total number of laps done within the race
# Time: Lap time set by the winner

data_list = pd.DataFrame(data_dictionary)
data_list
# Out:
#      Grand Prix        Date          Winner               Car  Laps     Time
# 0       Bahrain  2024-03-02  Max Verstappen   Red Bull Racing    57  1:31:45
# 1  Saudi Arabia  2024-03-09  Max Verstappen   Red Bull Racing    50  1:20:43
# 2     Australia  2024-03-24    Carlos Sainz           Ferrari    58  1:20:27
# 3         Japan  2024-04-07  Max Verstappen   Red Bull Racing    53  1:54:24
# 4         China  2024-04-21  Max Verstappen   Red Bull Racing    56  1:40:53
# 5         Miami  2024-05-05    Lando Norris  Mclaren Mercedes    57  1:30:50

# %% [markdown]
# Creating a dataframe from a list of dictionaries

# %%
data_list = [
    {'Grand Prix': 'Bahrain', 'Date': '2024-03-02', 'Winner': 'Max Verstappen', 'Car': 'Red Bull Racing', 'Laps': 57, 'Time': '1:31:45'},
    {'Grand Prix': 'Saudi Arabia', 'Date': '2024-03-09', 'Winner': 'Max Verstappen', 'Car': 'Red Bull Racing', 'Laps': 50, 'Time': '1:20:43'},
    {'Grand Prix': 'Australia', 'Date': '2024-03-24', 'Winner': 'Carlos Sainz', 'Car': 'Ferrari', 'Laps': 58, 'Time': '1:20:27'},
    {'Grand Prix': 'Japan', 'Date': '2024-04-07', 'Winner': 'Max Verstappen', 'Car': 'Red Bull Racing', 'Laps': 53, 'Time': '1:54:24'},
    {'Grand Prix': 'China', 'Date': '2024-04-21', 'Winner': 'Max Verstappen', 'Car': 'Red Bull Racing', 'Laps': 56, 'Time': '1:40:53'},
    {'Grand Prix': 'Miami', 'Date': '2024-05-05', 'Winner': 'Lando Norris', 'Car': 'Mclaren Mercedes', 'Laps': 57, 'Time': '1:30:50'}
]

# Grand Prix: Country of the F1 Championship it was held on
# Date: Date of the F1 Championship occured (all held in early 2024)
# Winner: The winner of the F1 Championship
# Car: Name of the F1 participant that won the F1 Championship
# Laps: Total number of laps done within the race
# Time: Lap time set by the winner on the last lap

data_dict = pd.DataFrame(data_list)
data_dict
# Out:
#      Grand Prix        Date          Winner               Car  Laps     Time
# 0       Bahrain  2024-03-02  Max Verstappen   Red Bull Racing    57  1:31:45
# 1  Saudi Arabia  2024-03-09  Max Verstappen   Red Bull Racing    50  1:20:43
# 2     Australia  2024-03-24    Carlos Sainz           Ferrari    58  1:20:27
# 3         Japan  2024-04-07  Max Verstappen   Red Bull Racing    53  1:54:24
# 4         China  2024-04-21  Max Verstappen   Red Bull Racing    56  1:40:53
# 5         Miami  2024-05-05    Lando Norris  Mclaren Mercedes    57  1:30:50

# %% [markdown]
# Selecting dataframe columns

# %%
print("Column Selection: Time")
data_dict['Time']
# Out:
# Column Selection: Time
# 0    1:31:45
# 1    1:20:43
# 2    1:20:27
# 3    1:54:24
# 4    1:40:53
# 5    1:30:50
# Name: Time, dtype: object

# %% [markdown]
# Selecting dataframe rows

# %%
print("Single Row Selection:")
data_dict.iloc[0]
# Out:
# Single Row Selection:
# Grand Prix            Bahrain
# Date               2024-03-02
# Winner         Max Verstappen
# Car           Red Bull Racing
# Laps                       57
# Time                  1:31:45
# Name: 0, dtype: object

# %%
print("Single Row Selection:")
data_dict.iloc[:4]
# Out:
# Single Row Selection:
#      Grand Prix        Date          Winner              Car  Laps     Time
# 0       Bahrain  2024-03-02  Max Verstappen  Red Bull Racing    57  1:31:45
# 1  Saudi Arabia  2024-03-09  Max Verstappen  Red Bull Racing    50  1:20:43
# 2     Australia  2024-03-24    Carlos Sainz          Ferrari    58  1:20:27
# 3         Japan  2024-04-07  Max Verstappen  Red Bull Racing    53  1:54:24
